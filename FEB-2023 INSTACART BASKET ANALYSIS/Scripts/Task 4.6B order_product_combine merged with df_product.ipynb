# %% [markdown]
# # Importing libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# importing orders_products_combined file as pd.read_pickle
df_orders_products_combined = pd.read_pickle(r'C:\Users\Babafemi Olayinka\Jupyter Notebook\FEB-2023 INSTACART BASKET ANALYSIS\Data\Prepared Data\orders_products_combined.pkl')

# %%
path = r'C:\Users\Babafemi Olayinka\Jupyter Notebook\FEB-2023 INSTACART BASKET ANALYSIS'

# %%
path
# Out:
# 'C:\\Users\\Babafemi Olayinka\\Jupyter Notebook\\FEB-2023 INSTACART BASKET ANALYSIS'

# %%
# importing orders_products_combined using path
df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2696\1411582626.py in <module>
#       1 # importing orders_products_combined using path
# ----> 2 df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'), index_col = False)
#
# TypeError: read_pickle() got an unexpected keyword argument 'index_col'

# %%
# checking the dimension and comparing it to the save df_merged_large file
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both

# %%
# import products from data
df_prods = pd.read_csv(r'C:\Users\Babafemi Olayinka\Jupyter Notebook\FEB-2023 INSTACART BASKET ANALYSIS\Data\Prepared Data\orders_wrangled.csv' , index_col = False)

# %%
df_prods
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                 0   2539329        1    prior             1          2
# 1                 1   2398795        1    prior             2          3
# 2                 2    473747        1    prior             3          3
# 3                 3   2254736        1    prior             4          4
# 4                 4    431534        1    prior             5          4
# ...             ...       ...      ...      ...           ...        ...
# 3421078     3421078   2266710   206209    prior            10          5
# 3421079     3421079   1854736   206209    prior            11          4
# 3421080     3421080    626363   206209    prior            12          1
# 3421081     3421081   2977660   206209    prior            13          1
# 3421082     3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
path
# Out:
# 'C:\\Users\\Babafemi Olayinka\\Jupyter Notebook\\FEB-2023 INSTACART BASKET ANALYSIS'

# %%
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# checking the column
df_prods.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2398795        1    prior             2          3
# 2           2    473747        1    prior             3          3
# 3           3   2254736        1    prior             4          4
# 4           4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_prods.drop(columns = ['Unnamed: 0'])
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# rewriting the df_prods without the column Unnamed : 0
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %% [markdown]
# # Merging the 2 df ( df_prods and df_orders_products_combined)

# %%
# merge the df. anothr wat to concatenate and make axis = 1
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'order_id', indicator = False)

# %%
df_orders_products_merged
# Out:
#           order_id  user_id_x  order_number_x  order_dow_x  \
# 0          2539329          1               1            2
# 1          2539329          1               1            2
# 2          2539329          1               1            2
# 3          2539329          1               1            2
# 4          2539329          1               1            2
# ...            ...        ...             ...          ...
# 32434484   2977660     206209              13            1
# 32434485   2977660     206209              13            1
# 32434486   2977660     206209              13            1
# 32434487   2977660     206209              13            1
# 32434488   2977660     206209              13            1
#
#           order_hour_of_day_x  days_since_prior_order_x  product_id  \
# 0                           8                       7.0         196
# 1                           8                       7.0       14084
# ...

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Using Concatenate because they have same number of column and rows.

# %%
# create a frame with default axis = 0
frames = [df_orders_products_combined, df_prods]

# %%
df_orders_products_merged = pd.concat(frames)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0       196.0                1.0        0.0   both
# 1                     7.0     14084.0                2.0        0.0   both
# 2                     7.0     12427.0                3.0        0.0   both
# 3                     7.0     26088.0                4.0        0.0   both
# 4                     7.0     26405.0                5.0        0.0   both
#
#   eval_set
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_orders_products_merged.shape
# Out:
# (35855572, 11)

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # There is a full match from my merged datasets. 100 % full match.

# %% [markdown]
# # Exporting my df_orders_products_merged as pickle file into my prepare data folder

# %%
path = r'C:\Users\Babafemi Olayinka\Jupyter Notebook\FEB-2023 INSTACART BASKET ANALYSIS'

# %%
path
# Out:
# 'C:\\Users\\Babafemi Olayinka\\Jupyter Notebook\\FEB-2023 INSTACART BASKET ANALYSIS'

# %%
# export my df_orders_products_combined as pkl format
df_orders_products_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
